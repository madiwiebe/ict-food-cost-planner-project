# %%
from stats_can import StatsCan
import requests

# %%
# function: update_tables() can be added at the end??

sc = StatsCan()

# %%
df = sc.table_to_df('18-10-0245-01')

# %%
df
# Out:
#         REF_DATE               GEO           DGUID  \
# 0     2017-01-01            Canada  2016A000011124
# 1     2017-01-01            Canada  2016A000011124
# 2     2017-01-01            Canada  2016A000011124
# 3     2017-01-01            Canada  2016A000011124
# 4     2017-01-01            Canada  2016A000011124
# ...          ...               ...             ...
# 99133 2023-10-01  British Columbia     2016A000259
# 99134 2023-10-01  British Columbia     2016A000259
# 99135 2023-10-01  British Columbia     2016A000259
# 99136 2023-10-01  British Columbia     2016A000259
# 99137 2023-10-01  British Columbia     2016A000259
#
#                                   Products      UOM UOM_ID SCALAR_FACTOR  \
# 0          Beef stewing cuts, per kilogram  Dollars     81         units
# 1        Beef striploin cuts, per kilogram  Dollars     81         units
# 2      Beef top sirloin cuts, per kilogram  Dollars     81         units
# ...

# %%
df['VECTOR'].unique()
# Out:
# ['v1353834271', 'v1353834272', 'v1353834273', 'v1353834311', 'v1353834274', ..., 'v1458870265', 'v1353834714', 'v1353834715', 'v1353834716', 'v1458870250']
# Length: 1209
# Categories (1209, object): ['v1159446976', 'v1159446977', 'v1159446978', 'v1159446979', ..., 'v1458870264', 'v1458870265', 'v1458870266', 'v1458870267']

# %%
df['VECTOR'].unique().to_list()
# Out:
# /var/folders/_l/rvfsqjvn4fl7npqhjz_rd08h0000gn/T/ipykernel_2693/3989485598.py:1: FutureWarning: Categorical.to_list is deprecated and will be removed in a future version. Use obj.tolist() instead
#   df['VECTOR'].unique().to_list()
# ['v1353834271',
#  'v1353834272',
#  'v1353834273',
#  'v1353834311',
#  'v1353834274',
#  'v1353834275',
#  'v1353834276',
#  'v1353834312',
#  'v1353834277',
#  'v1353834278',
#  'v1353834279',
#  'v1353834313',
#  'v1353834280',
#  'v1353834281',
#  'v1458869929',
#  'v1458869931',
#  'v1353834314',
#  'v1353834282',
#  'v1458869922',
#  'v1353834283',
#  'v1353834284',
#  'v1353834285',
#  'v1458869932',
#  'v1458869923',
#  'v1353834286',
#  'v1353834287',
#  'v1458869921',
#  'v1353834288',
#  'v1353834289',
#  'v1353834290',
#  'v1353834291',
#  'v1353834292',
#  'v1353834293',
#  'v1353834294',
#  'v1353834295',
#  'v1353834296',
#  'v1353834315',
#  'v1353834297',
#  'v1353834298',
#  'v1458869934',
#  'v1353834299',
#  'v1353834300',
# ...

# %%
len(df['Products'].unique())
# Out:
# 110

# %%
# beef stewing cuts for canada only
df2 = sc.vectors_to_df('v1353834271')

# %%
# beef stewing cuts for canada + 10 provinces
df3 = sc.vectors_to_df(['v1353834271','v1159446976','v1159447015','v1159447055','v1159447095','v1159447135','v1159447175','v1159447215','v1159447255','v1159447295','v1159447335'])

# %%
df3
# Out:
#             v1353834271  v1159446976  v1159447015  v1159447055  v1159447095  \
# REF_DATE
# 2017-01-01        12.66        13.57        13.33        13.12        13.33
# 2017-02-01        13.12        14.24        13.82        13.47        13.77
# 2017-03-01        13.51        14.07        13.63        13.55        13.83
# 2017-04-01        13.29        13.10        12.58        12.26        12.85
# 2017-05-01        14.08        13.75        12.78        12.61        13.42
# ...                 ...          ...          ...          ...          ...
# 2023-06-01        19.63        19.39        19.35        18.42        19.39
# 2023-07-01        19.48        18.58        18.96        17.56        18.23
# 2023-08-01        16.23        19.93        20.11        19.00        15.09
# 2023-09-01        18.50        17.63        17.51        16.66        17.73
# 2023-10-01        17.66        17.45        17.08        16.55        17.83
#
# ...

# %%
sc.downloaded_tables
# Out:
# ['18100245']

# %%
sc.get_code_sets
# Out:
# <function stats_can.api_class.StatsCan.get_code_sets()>

# %%
sc.table_to_df('18-10-0245')
# Out:
#         REF_DATE               GEO           DGUID  \
# 0     2017-01-01            Canada  2016A000011124
# 1     2017-01-01            Canada  2016A000011124
# 2     2017-01-01            Canada  2016A000011124
# 3     2017-01-01            Canada  2016A000011124
# 4     2017-01-01            Canada  2016A000011124
# ...          ...               ...             ...
# 99133 2023-10-01  British Columbia     2016A000259
# 99134 2023-10-01  British Columbia     2016A000259
# 99135 2023-10-01  British Columbia     2016A000259
# 99136 2023-10-01  British Columbia     2016A000259
# 99137 2023-10-01  British Columbia     2016A000259
#
#                                   Products      UOM UOM_ID SCALAR_FACTOR  \
# 0          Beef stewing cuts, per kilogram  Dollars     81         units
# 1        Beef striploin cuts, per kilogram  Dollars     81         units
# 2      Beef top sirloin cuts, per kilogram  Dollars     81         units
# ...

# %%
sc.vector_metadata('v1353834271')
# Out:
# [{'responseStatusCode': 0,
#   'productId': 18100245,
#   'coordinate': '11.1.0.0.0.0.0.0.0.0',
#   'vectorId': 1353834271,
#   'frequencyCode': 6,
#   'scalarFactorCode': 0,
#   'decimals': 2,
#   'terminated': 0,
#   'SeriesTitleEn': 'Canada;Beef stewing cuts, per kilogram',
#   'SeriesTitleFr': 'Canada;Boeuf à ragoût, par kilogramme',
#   'memberUomCode': 81}]

# %%
sc.vectors_to_df_remote('v1353834271', periods=120)

# only goes back to 2017 Jan
# Out:
#             v1353834271
# refPer
# 2017-01-01        12.66
# 2017-02-01        13.12
# 2017-03-01        13.51
# 2017-04-01        13.29
# 2017-05-01        14.08
# ...                 ...
# 2023-06-01        19.63
# 2023-07-01        19.48
# 2023-08-01        16.23
# 2023-09-01        18.50
# 2023-10-01        17.66
#
# [82 rows x 1 columns]

# %%
# get tables that has the vector

sc.get_tables_for_vectors('v1353834271')
# Out:
# {1353834271: '18100245', 'all_tables': ['18100245']}

# %%
list = ['']
