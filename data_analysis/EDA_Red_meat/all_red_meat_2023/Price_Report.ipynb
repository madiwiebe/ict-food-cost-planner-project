# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Loading

# %%
df_chicken= pd.read_csv('/content/drive/MyDrive/food-cost-planner Project/data processing/Corrected_Chicken_organized.csv')
df_chicken.sample(5)
# Out:
#      Start Date    End Date                       Product name  \
# 41   2023-01-29  2023-02-25   Chicken bone-in breast with skin
# 43   2023-03-26  2023-04-22   Chicken bone-in breast with skin
# 29   2023-09-10  2023-10-07  Chicken boneless breast, skinless
# 100  2023-01-01  2023-01-28                     Ground chicken
# 7    2023-07-16  2023-08-12                Fresh whole chicken
#
#     British Columbia Alberta Saskatchewan Manitoba Ontario Quebec  \
# 41             13,68   22,45        14,27    13,94   12,67  15,16
# 43             13,31   22,05        12,57    12,32    9,29  15,53
# 29             15,98   15,78         15,4    15,47    14,3  15,07
# 100            13,77    13,4        12,57    12,41   13,58  15,34
# 7               8,78    7,68         7,44     7,17    7,81   9,17
#
#     Maritimes (1) Newfoundland and Labrador Canada (2)
# 41          11,17                      9,98      12,06
# 43          10,21                     10,14      10,23
# ...

# %%
df_eggs= pd.read_csv('/content/drive/MyDrive/food-cost-planner Project/data processing/Corrected_Eggs_Organized.csv')
df_eggs.sample(5)
# Out:
#     Start Date    End Date              Product name British Columbia Alberta  \
# 46  2023-06-18  2023-07-15        Large Organic Eggs             7,55    7,09
# 31  2023-01-29  2023-02-25     Large Free Range Eggs             6,94    6,19
# 8   2023-08-13  2023-09-09  Large Regular White Eggs             4,14    4,17
# 22  2023-02-26  2023-03-25       Large Free Run Eggs              6,4    6,34
# 58  2023-08-13  2023-09-09        Large Omega-3 Eggs             5,53    5,84
#
#    Saskatchewan Manitoba Ontario Quebec Maritimes (1)  \
# 46         6,92     6,86    7,32   7,57          7,59
# 31         6,36     6,06    6,24   6,64          7,97
# 8          4,05     4,06    3,78   3,54          4,45
# 22         5,46     6,22    6,73   5,51          5,66
# 58         6,05     5,95     5,4   5,66          5,41
#
#    Newfoundland and Labrador Canada (2)
# 46                      7,65       7,36
# 31                         -       6,65
# 8                        4,5       3,87
# ...

# %%
df_pork= pd.read_csv('/content/drive/MyDrive/food-cost-planner Project/data processing/Corrected_Pork_Organized.csv')
df_pork.sample(5)
# Out:
#     Start Date    End Date     Product name British Columbia Alberta  \
# 24  2023-04-23  2023-05-20  Pork Tenderloin            12,05   11,04
# 48  2023-08-13  2023-09-09      Pork Grinds            10,14    9,61
# 19  2023-09-10  2023-10-07       Pork Roast            11,39   10,38
# 17  2023-07-16  2023-08-12       Pork Roast            11,16   10,56
# 26  2023-06-18  2023-07-15  Pork Tenderloin            12,47   10,99
#
#    Saskatchewan Manitoba Ontario Quebec Maritimes (1)  \
# 24         11,4    11,16    9,76  10,14         10,35
# 48         9,81      9,6    10,1    7,9         10,78
# 19        10,34    10,53   11,27   5,92         10,06
# 17        10,91    10,91    9,73   8,66          9,97
# 26        11,14    11,04    9,64   9,56          11,5
#
#    Newfoundland and Labrador Canada (2)
# 24                     10,31      10,36
# 48                      9,65       8,91
# 19                     10,53       8,37
# 17                     10,07       9,76
# ...

# %%
df_turkey= pd.read_csv('/content/drive/MyDrive/food-cost-planner Project/data processing/Corrected_Turkey_Organized.csv')
df_turkey.sample(5)
# Out:
#     Start Date    End Date            Product name British Columbia Alberta  \
# 15  2023-05-21  2023-06-17     Whole frozen turkey             4,52    3,78
# 3   2023-03-26  2023-04-22      Whole fresh turkey             4,41    4,97
# 46  2023-06-18  2023-07-15  Turkey thigh (Bone-in)            11,53   11,22
# 41  2023-01-29  2023-02-25  Turkey thigh (Bone-in)            11,84   11,43
# 1   2023-01-29  2023-02-25      Whole fresh turkey             6,58    7,09
#
#    Saskatchewan Manitoba Ontario Quebec Maritimes (1)  \
# 15         3,48     3,94    4,72   5,31           6,6
# 3          5,12     4,98     4,2   5,72          4,81
# 46        11,84    11,09   11,27   10,4         10,58
# 41        11,35    10,95   10,75  10,68          9,54
# 1           7,2     6,64    6,73   7,74          6,73
#
#    Newfoundland and Labrador Canada (2)
# 15                      6,96          5
# 3                       5,43       4,56
# 46                      9,55      11,13
# ...

# %% [markdown]
# # Data Inspection

# %%
df_chicken.head()
df_chicken.info()
df_chicken.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Start Date                 110 non-null    object
#  1   End Date                   110 non-null    object
#  2   Product name               110 non-null    object
#  3   British Columbia           110 non-null    object
#  4   Alberta                    110 non-null    object
#  5   Saskatchewan               110 non-null    object
#  6   Manitoba                   110 non-null    object
#  7   Ontario                    110 non-null    object
#  8   Quebec                     110 non-null    object
#  9   Maritimes (1)              110 non-null    object
#  10  Newfoundland and Labrador  110 non-null    object
#  11  Canada (2)                 110 non-null    object
# dtypes: object(12)
# memory usage: 10.4+ KB
# ...

# %%
df_eggs.head()
df_eggs.info()
df_eggs.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Start Date                 60 non-null     object
#  1   End Date                   60 non-null     object
#  2   Product name               60 non-null     object
#  3   British Columbia           60 non-null     object
#  4   Alberta                    60 non-null     object
#  5   Saskatchewan               60 non-null     object
#  6   Manitoba                   60 non-null     object
#  7   Ontario                    60 non-null     object
#  8   Quebec                     60 non-null     object
#  9   Maritimes (1)              60 non-null     object
#  10  Newfoundland and Labrador  60 non-null     object
#  11  Canada (2)                 60 non-null     object
# dtypes: object(12)
# memory usage: 5.8+ KB
# ...

# %%
df_pork.head()
df_pork.info()
df_pork.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Start Date                 50 non-null     object
#  1   End Date                   50 non-null     object
#  2   Product name               50 non-null     object
#  3   British Columbia           50 non-null     object
#  4   Alberta                    50 non-null     object
#  5   Saskatchewan               50 non-null     object
#  6   Manitoba                   50 non-null     object
#  7   Ontario                    50 non-null     object
#  8   Quebec                     50 non-null     object
#  9   Maritimes (1)              50 non-null     object
#  10  Newfoundland and Labrador  50 non-null     object
#  11  Canada (2)                 50 non-null     object
# dtypes: object(12)
# memory usage: 4.8+ KB
# ...

# %%
df_turkey.head()
df_turkey.info()
df_turkey.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Start Date                 70 non-null     object
#  1   End Date                   70 non-null     object
#  2   Product name               70 non-null     object
#  3   British Columbia           70 non-null     object
#  4   Alberta                    70 non-null     object
#  5   Saskatchewan               70 non-null     object
#  6   Manitoba                   70 non-null     object
#  7   Ontario                    70 non-null     object
#  8   Quebec                     70 non-null     object
#  9   Maritimes (1)              70 non-null     object
#  10  Newfoundland and Labrador  70 non-null     object
#  11  Canada (2)                 70 non-null     object
# dtypes: object(12)
# memory usage: 6.7+ KB
# ...

# %% [markdown]
# #Data Cleaning

# %%
df_chicken.isnull().sum()
# Out:
# Start Date                   0
# End Date                     0
# Product name                 0
# British Columbia             0
# Alberta                      0
# Saskatchewan                 0
# Manitoba                     0
# Ontario                      0
# Quebec                       0
# Maritimes (1)                0
# Newfoundland and Labrador    0
# Canada (2)                   0
# dtype: int64

# %%
df_eggs.isnull().sum()
# Out:
# Start Date                   0
# End Date                     0
# Product name                 0
# British Columbia             0
# Alberta                      0
# Saskatchewan                 0
# Manitoba                     0
# Ontario                      0
# Quebec                       0
# Maritimes (1)                0
# Newfoundland and Labrador    0
# Canada (2)                   0
# dtype: int64

# %%
df_pork.isnull().sum()
# Out:
# Start Date                   0
# End Date                     0
# Product name                 0
# British Columbia             0
# Alberta                      0
# Saskatchewan                 0
# Manitoba                     0
# Ontario                      0
# Quebec                       0
# Maritimes (1)                0
# Newfoundland and Labrador    0
# Canada (2)                   0
# dtype: int64

# %%
df_turkey.isnull().sum()
# Out:
# Start Date                   0
# End Date                     0
# Product name                 0
# British Columbia             0
# Alberta                      0
# Saskatchewan                 0
# Manitoba                     0
# Ontario                      0
# Quebec                       0
# Maritimes (1)                0
# Newfoundland and Labrador    0
# Canada (2)                   0
# dtype: int64

# %%
# Count the duplicates chicken
duplicates_chicken = df_chicken.duplicated()
number_of_duplicates_chicken = duplicates_chicken.sum()
print(number_of_duplicates_chicken)
# Out:
# 0

# %%
# Count the duplicates eggs
duplicates_eggs = df_eggs.duplicated()
number_of_duplicates_eggs = duplicates_eggs.sum()
print(number_of_duplicates_eggs)
# Out:
# 0

# %%
# Count the duplicates pork
duplicates_pork = df_pork.duplicated()
number_of_duplicates_pork = duplicates_pork.sum()
print(number_of_duplicates_pork)
# Out:
# 0

# %%
# Count the duplicates pork
duplicates_pork = df_pork.duplicated()
number_of_duplicates_pork = duplicates_pork.sum()
print(number_of_duplicates_pork)
# Out:
# 0

# %%
# Count the duplicates turkey
duplicates_turkey = df_turkey.duplicated()
number_of_duplicates_turkey = duplicates_turkey.sum()
print(number_of_duplicates_turkey)
# Out:
# 0

# %% [markdown]
# #Data Type Conversion:

# %%
#Data Transformation
