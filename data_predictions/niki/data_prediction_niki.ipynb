# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("national_MRA_clean.csv")
df
# Out:
#              date location vectorid  price               product  \
# 0      1995-01-01   Canada  v735165  10.17           Round steak
# 1      1995-01-01   Canada  v735176  11.25         Sirloin steak
# 2      1995-01-01   Canada  v735187  12.08       Prime rib roast
# 3      1995-01-01   Canada  v735198   7.23           Blade roast
# 4      1995-01-01   Canada  v735209   7.12          Stewing beef
# ...           ...      ...      ...    ...                   ...
# 15649  2022-02-01   Canada  v735202   7.10       Coffee, instant
# 15650  2022-02-01   Canada  v735203   4.49                  Tea
# 15651  2022-02-01   Canada  v735204   4.45  Cooking or salad oil
# 15652  2022-02-01   Canada  v735205   1.28          Soup, canned
# 15653  2022-02-01   Canada  v735207   2.89         Peanut butter
#
#        unit_quantity         unit     category
# 0                1.0     kilogram      Protein
# 1                1.0     kilogram      Protein
# 2                1.0     kilogram      Protein
# 3                1.0     kilogram      Protein
# 4                1.0     kilogram      Protein
# ...              ...          ...          ...
# 15649          200.0        grams    Beverages
# 15650           72.0         bags    Beverages
# 15651            1.0        litre         Oils
# 15652          284.0  millilitres  Other_foods
# 15653          500.0        grams      Protein
#
# [15654 rows x 8 columns]

# %%
from datetime import date

df['date_ordinal'] = pd.to_datetime(df['date']).apply(lambda date: date.toordinal())

# %%
df.describe()
# Out:
#               price  unit_quantity   date_ordinal
# count  15654.000000   15654.000000   15654.000000
# mean       4.439426     148.777294  733156.622014
# std        4.614685     226.969813    2850.922756
# min        0.580000       1.000000  728294.000000
# 25%        1.750000       1.000000  730667.000000
# 50%        2.910000       1.360000  733133.000000
# 75%        4.890000     284.000000  735630.000000
# max       44.820000     796.000000  738187.000000

# %%
cdf = df[['date','price','product','category', 'date_ordinal']]
cdf
# Out:
#              date  price               product     category  date_ordinal
# 0      1995-01-01  10.17           Round steak      Protein        728294
# 1      1995-01-01  11.25         Sirloin steak      Protein        728294
# 2      1995-01-01  12.08       Prime rib roast      Protein        728294
# 3      1995-01-01   7.23           Blade roast      Protein        728294
# 4      1995-01-01   7.12          Stewing beef      Protein        728294
# ...           ...    ...                   ...          ...           ...
# 15649  2022-02-01   7.10       Coffee, instant    Beverages        738187
# 15650  2022-02-01   4.49                  Tea     Beverages        738187
# 15651  2022-02-01   4.45  Cooking or salad oil         Oils        738187
# 15652  2022-02-01   1.28          Soup, canned  Other_foods        738187
# 15653  2022-02-01   2.89         Peanut butter      Protein        738187
#
# [15654 rows x 5 columns]

# %%
cdf.dtypes
# Out:
# date             object
# price           float64
# product          object
# category         object
# date_ordinal      int64
# dtype: object

# %%
cdf['date'] = pd.to_datetime(df['date'])
cdf['product'].astype(str)
cdf['category'].astype(str)

cdf.dtypes
# Out:
# /var/folders/_l/rvfsqjvn4fl7npqhjz_rd08h0000gn/T/ipykernel_3130/458416524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['date'] = pd.to_datetime(df['date'])
# date            datetime64[ns]
# price                  float64
# product                 object
# category                object
# date_ordinal             int64
# dtype: object

# %%
cdf.head(52)
# Out:
#          date  price                        product     category  date_ordinal
# 0  1995-01-01  10.17                    Round steak      Protein        728294
# 1  1995-01-01  11.25                  Sirloin steak      Protein        728294
# 2  1995-01-01  12.08                Prime rib roast      Protein        728294
# 3  1995-01-01   7.23                    Blade roast      Protein        728294
# 4  1995-01-01   7.12                   Stewing beef      Protein        728294
# 5  1995-01-01   3.73                    Ground beef      Protein        728294
# 6  1995-01-01   8.36                     Pork chops      Protein        728294
# 7  1995-01-01   4.90                     Butt roast      Protein        728294
# 8  1995-01-01   3.72                        Chicken      Protein        728294
# 9  1995-01-01   3.00                          Bacon      Protein        728294
# 10 1995-01-01   2.62                        Wieners      Protein        728294
# 11 1995-01-01   3.64                  Canned salmon      Protein        728294
# 12 1995-01-01   1.34               Homogenized milk    Beverages        728294
# 13 1995-01-01   1.30            Partly skimmed milk    Beverages        728294
# 14 1995-01-01   2.83                         Butter      Protein        728294
# 15 1995-01-01   2.49        Processed cheese slices        Dairy        728294
# 16 1995-01-01   0.99                Evaporated milk    Beverages        728294
# 17 1995-01-01   1.56                           Eggs      Protein        728294
# 18 1995-01-01   1.27                          Bread       Grains        728294
# 19 1995-01-01   1.87                  Soda crackers       Grains        728294
# 20 1995-01-01   0.96                       Macaroni       Grains        728294
# 21 1995-01-01   3.27                          Flour       Grains        728294
# 22 1995-01-01   3.03                    Corn flakes       Grains        728294
# 23 1995-01-01   2.08                         Apples   Veg_Fruits        728294
# 24 1995-01-01   1.37                        Bananas   Veg_Fruits        728294
# 25 1995-01-01   1.31                    Grapefruits   Veg_Fruits        728294
# 26 1995-01-01   1.55                        Oranges   Veg_Fruits        728294
# 27 1995-01-01   1.41                    Apple juice    Beverages        728294
# 28 1995-01-01   1.63                   Orange juice    Beverages        728294
# 29 1995-01-01   0.84                        Cabbage   Veg_Fruits        728294
# 30 1995-01-01   1.18                        Carrots   Veg_Fruits        728294
# 31 1995-01-01   2.63                         Celery   Veg_Fruits        728294
# 32 1995-01-01   5.62                      Mushrooms   Veg_Fruits        728294
# 33 1995-01-01   1.04                         Onions   Veg_Fruits        728294
# 34 1995-01-01   2.70                       Potatoes   Veg_Fruits        728294
# 35 1995-01-01   1.71  French fried potatoes, frozen       Frozen        728294
# 36 1995-01-01   0.80            Baked beans, canned  Plant_based        728294
# 37 1995-01-01   1.26               Tomatoes, canned   Veg_Fruits        728294
# 38 1995-01-01   1.45                   Tomato juice    Beverages        728294
# 39 1995-01-01   2.41                        Ketchup  Other_foods        728294
# 40 1995-01-01   1.95                   Sugar, white  Other_foods        728294
# 41 1995-01-01   4.22                Coffee, roasted    Beverages        728294
# 42 1995-01-01   7.02                Coffee, instant    Beverages        728294
# 43 1995-01-01   2.64                           Tea     Beverages        728294
# 44 1995-01-01   2.97           Cooking or salad oil         Oils        728294
# 45 1995-01-01   0.72                   Soup, canned  Other_foods        728294
# 46 1995-01-01   2.65                  Peanut butter      Protein        728294
# 47 1995-01-01   1.29       Fruit flavoured crystals    Beverages        728294
# 48 1995-01-01   1.39         Soft drinks, cola type    Beverages        728294
# 49 1995-01-01   1.50   Soft drinks, lemon-lime type    Beverages        728294
# 50 1995-02-01  10.29                    Round steak      Protein        728325
# 51 1995-02-01  11.43                  Sirloin steak      Protein        728325

# %%
grouped = cdf.groupby(['category'])

protein = grouped.get_group("Protein")
beverages = grouped.get_group("Beverages")
dairy = grouped.get_group("Dairy")
grains = grouped.get_group("Grains")
veg_fruits = grouped.get_group("Veg_Fruits")
frozen = grouped.get_group("Frozen")
plant_based = grouped.get_group("Plant_based")
others = grouped.get_group("Other_foods")

# %%
round_steak = cdf[(cdf['product'] == 'Round steak')]
plt.scatter(round_steak.date, round_steak.price, color='blue')
plt.xlabel("Timeline")
plt.ylabel("Price")
plt.show()

# %%
round_steak
# Out:
#             date  price      product category  date_ordinal
# 0     1995-01-01  10.17  Round steak  Protein        728294
# 50    1995-02-01  10.29  Round steak  Protein        728325
# 100   1995-03-01  10.12  Round steak  Protein        728353
# 150   1995-04-01  10.38  Round steak  Protein        728384
# 200   1995-05-01  10.00  Round steak  Protein        728414
# ...          ...    ...          ...      ...           ...
# 15439 2021-10-01  20.34  Round steak  Protein        738064
# 15482 2021-11-01  19.77  Round steak  Protein        738095
# 15525 2021-12-01  19.66  Round steak  Protein        738125
# 15568 2022-01-01  20.03  Round steak  Protein        738156
# 15611 2022-02-01  19.79  Round steak  Protein        738187
#
# [326 rows x 5 columns]

# %%
msk = np.random.rand(len(round_steak)) < 0.8
train = round_steak[msk]
test = round_steak[~msk]

# %%
train
# Out:
#             date  price      product category  date_ordinal
# 0     1995-01-01  10.17  Round steak  Protein        728294
# 50    1995-02-01  10.29  Round steak  Protein        728325
# 200   1995-05-01  10.00  Round steak  Protein        728414
# 350   1995-08-01  10.07  Round steak  Protein        728506
# 400   1995-09-01  10.08  Round steak  Protein        728537
# ...          ...    ...          ...      ...           ...
# 15439 2021-10-01  20.34  Round steak  Protein        738064
# 15482 2021-11-01  19.77  Round steak  Protein        738095
# 15525 2021-12-01  19.66  Round steak  Protein        738125
# 15568 2022-01-01  20.03  Round steak  Protein        738156
# 15611 2022-02-01  19.79  Round steak  Protein        738187
#
# [263 rows x 5 columns]

# %%
test
# Out:
#             date  price      product category  date_ordinal
# 100   1995-03-01  10.12  Round steak  Protein        728353
# 150   1995-04-01  10.38  Round steak  Protein        728384
# 250   1995-06-01  10.19  Round steak  Protein        728445
# 300   1995-07-01  10.26  Round steak  Protein        728475
# 550   1995-12-01   9.88  Round steak  Protein        728628
# ...          ...    ...          ...      ...           ...
# 14880 2020-09-01  18.71  Round steak  Protein        737669
# 15009 2020-12-01  17.66  Round steak  Protein        737760
# 15138 2021-03-01  17.97  Round steak  Protein        737850
# 15267 2021-06-01  18.71  Round steak  Protein        737942
# 15396 2021-09-01  20.01  Round steak  Protein        738034
#
# [63 rows x 5 columns]

# %%
# Train data distribution

plt.scatter(train.date_ordinal, train.price, color='blue')
plt.xlabel("Date Ordinal")
plt.ylabel("Price")
plt.show()

# %%
# Modeling

regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['date_ordinal']])
train_y = np.asanyarray(train[['price']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.0011185]]
# Intercept:  [-806.61705277]

# %%
# Plot outputs 

plt.scatter(train.date_ordinal, train.price, color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Date Ordinal")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
test_x = np.asanyarray(test[['date_ordinal']])
test_y = np.asanyarray(test[['price']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_))
# Out:
# Mean absolute error: 1.06
# Residual sum of squares (MSE): 1.62
# R2-score: 0.84
